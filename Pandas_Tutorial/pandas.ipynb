# %% [markdown]
# # Pandas Practice Tutorial
# This file explains all about the pandas

# %% [markdown]
# - How to install pandas

# %%
# pip install pandas 
# pip install numpy

# %% [markdown]
# - How to import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Object Creation

# %%
s=pd.Series([1,2,5,6,np.nan,7,8])
s
# Out:
# 0    1.0
# 1    2.0
# 2    5.0
# 3    6.0
# 4    NaN
# 5    7.0
# 6    8.0
# dtype: float64

# %%
date=pd.date_range("20220101",periods=4)
date
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04'], dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(4,4),index=list("1234"),columns=["A","B","C","D"])
df
# Out:
#           A         B         C         D
# 1  1.356854 -1.817602  0.661117  0.867663
# 2  2.664971 -0.242173 -0.763959  0.890603
# 3  0.788120  0.247153  0.306972 -0.600117
# 4  2.327342 -0.220029  0.294685 -0.091503

# %% [markdown]
# # Data Frame through Dictionary

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# Sex     object
# dtype: object

# %% [markdown]
# # Uploading a dummy Data of Store
# And performs some basic operations

# %%
store=pd.read_csv("Stores.csv")
store.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
store.head(2)
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820

# %%
store.tail(2)
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340

# %%
store.index
# Out:
# RangeIndex(start=0, stop=896, step=1)

# %%
s.to_numpy()
# Out:
# array([ 1.,  2.,  5.,  6., nan,  7.,  8.])

# %%
store.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %% [markdown]
# # Transpose Data
# Transpose converts columns into rows and rows into column and vice versa.

# %%
store.T
# Out:
#                         0      1      2      3      4      5      6      7    \
# Store ID                  1      2      3      4      5      6      7      8
# Store_Area             1659   1461   1340   1451   1770   1442   1542   1261
# Items_Available        1961   1752   1609   1748   2111   1733   1858   1507
# Daily_Customer_Count    530    210    720    620    450    760   1030   1020
# Store_Sales           66490  39820  54010  53730  46620  45260  72240  37720
#
#                         8      9    ...    886    887    888    889    890  \
# Store ID                  9     10  ...    887    888    889    890    891
# Store_Area             1090   1030  ...   1655   1156   1451   1539   1549
# Items_Available        1321   1235  ...   1986   1398   1734   1829   1851
# Daily_Customer_Count    680   1130  ...   1150    140    670    650   1220
# Store_Sales           46310  44150  ...  77430  92370  34880  46580  70620
#
#                         891    892    893    894    895
# Store ID                892    893    894    895    896
# Store_Area             1582   1387   1200   1299   1174
# Items_Available        1910   1663   1436   1560   1429
# Daily_Customer_Count   1080    850   1060    770   1110
# Store_Sales           66390  82080  76440  96610  54340
#
# [5 rows x 896 columns]

# %% [markdown]
# # Sorting Data

# %% [markdown]
# The following code sorts the data row wise because axis=0. And (False,True ) describe
# to ascend data in ascending order or in decending order.\
# **Note** :: If we want to sort data column wise then we use axis=1, and remaning process is same.

# %%
store.sort_index(axis=0,ascending=False).head()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 895        896        1174             1429                  1110        54340
# 894        895        1299             1560                   770        96610
# 893        894        1200             1436                  1060        76440
# 892        893        1387             1663                   850        82080
# 891        892        1582             1910                  1080        66390

# %%
store.sort_index(axis=1,ascending=True).head()
# Out:
#    Daily_Customer_Count  Items_Available  Store ID   Store_Area  Store_Sales
# 0                   530             1961          1        1659        66490
# 1                   210             1752          2        1461        39820
# 2                   720             1609          3        1340        54010
# 3                   620             1748          4        1451        53730
# 4                   450             2111          5        1770        46620

# %%
store.sort_values(by="Store_Area",ascending=True).head()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 158        159         775              932                  1090        42530
# 865        866         780              951                   790        25600
# 744        745         854             1018                   660        77740
# 549        550         869             1050                   850        52540
# 72          73         891             1073                   630        67370

# %% [markdown]
# # Filtering Data

# %%
# Column wise filtering
store["Store ID "].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Store ID , dtype: int64

# %%
# Row wise filtering 
store[0:4]
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730

# %% [markdown]
# # Loc and Iloc To Extract Data
# - Loc
#    - In loc function we can extract data of rows through index no and data of Columns through it's name
#       - Last element is not exclusive

# %%
store.loc[:,:].head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
store.loc[1:2,["Store_Area","Store_Sales"]].head()
# Out:
#    Store_Area  Store_Sales
# 1        1461        39820
# 2        1340        54010

# %%
store.loc[3:4,["Items_Available","Store_Sales"]]
# Out:
#    Items_Available  Store_Sales
# 3             1748        53730
# 4             2111        46620

# %% [markdown]
# - Iloc
#     - In iloc we can extract data of Rows and columns through it's index numbers
#         - Last element is exclusive but columns last index is not exclusive

# %%
store.iloc[:,:].head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
store.iloc[0:2,0:3]
# Out:
#    Store ID   Store_Area  Items_Available
# 0          1        1659             1961
# 1          2        1461             1752

# %% [markdown]
# # Booleans Operators

# %%
store[store["Store_Area"]<1000].head()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 41          42         965             1152                   600        48140
# 72          73         891             1073                   630        67370
# 158        159         775              932                  1090        42530
# 165        166         955             1133                   580        46140
# 203        204         992             1192                   900        34180

# %%
store[store<10].head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0        1.0         NaN              NaN                   NaN          NaN
# 1        2.0         NaN              NaN                   NaN          NaN
# 2        3.0         NaN              NaN                   NaN          NaN
# 3        4.0         NaN              NaN                   NaN          NaN
# 4        5.0         NaN              NaN                   NaN          NaN

# %% [markdown]
# # Copy Method
# - This function copies the data of one variable into another

# %%
store1=store.copy()
store1.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %% [markdown]
# # Pandas Study Case
# # Kashti Data Set

# %% [markdown]
# - Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
kashti=sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Saving Data into .csv file

# %%
kashti.to_csv("kashti.xlxs")

# %% [markdown]
# # Droping Columns and Rows
# Droping Rows

# %%
row_drop=kashti.drop([2,3],axis=0).head()
row_drop
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True

# %% [markdown]
# Droping Columns from existing data

# %%
row_drop.drop(["deck"],axis=1)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 4    man        True  Southampton    no   True
# 5    man        True   Queenstown    no   True
# 6    man        True  Southampton    no   True

# %% [markdown]
# # Basic Statistics

# %%
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
kashti.mean()
# Out:
# C:\Users\chmud\AppData\Local\Temp/ipykernel_6388/3332994036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
kashti.value_counts("survived")
# Out:
# survived
# 0    549
# 1    342
# dtype: int64

# %%
kashti.groupby(["sex"]).mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
kashti.groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  0.457447  106.125798
#        Second  0.921053     2.0  28.722973  0.486842  0.605263   21.970121
#        Third   0.500000     3.0  21.750000  0.895833  0.798611   16.118810
# male   First   0.368852     1.0  41.281386  0.311475  0.278689   67.226127
#        Second  0.157407     2.0  30.740707  0.342593  0.222222   19.741782
#        Third   0.135447     3.0  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.361702
#        Second    0.000000  0.421053
#        Third     0.000000  0.416667
# male   First     0.975410  0.614754
#        Second    0.916667  0.666667
#        Third     0.919308  0.760807

# %%
kashti[kashti["age"]<18].groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558
